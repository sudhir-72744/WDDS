# %% [markdown]
# from google.colab import drive
# drive.mount('/content/drive',force_remount=True)

# %%
# rm -rf m5000

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd ..
# Out:
# /

# %%
# !cp '/content/drive/MyDrive/m30000.zip' content

# %%
cd content
# Out:
# /content

# %%
# !unzip m30000.zip -d m30000
# Out:
# Archive:  m30000.zip
# replace m30000/Black chaff/008c03cb-b359-41f6-ace9-7dc6a950c2fb.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import os

folder_path = "m30000/"  # Replace with your folder path

# List all files in the folder
file_list = os.listdir(folder_path)

# Get the number of files
num_files = len(file_list)

print("Number of files in the folder:", num_files)
# Out:
# Number of files in the folder: 8

# %%
import tensorflow as tf

directory="m30000"
dataset=tf.keras.utils.image_dataset_from_directory(
    directory,
    shuffle= True,
    batch_size=32,
    image_size=(256, 256),

)
# Out:
# Found 2826 files belonging to 8 classes.

# %%
class_names=dataset.class_names
class_names
# Out:
# ['Black chaff',
#  'Brown rust',
#  'Crown and Root Rot',
#  'Healthy Wheat',
#  'Leaf Rust',
#  'Powdery mildew',
#  'Wheat Loose Smut',
#  'Yellow rust']

# %%
def get_dataset_partition(ds, train_split=0.7, val_split=0.1, test_split=0.2, shuffle=True, shuffle_size=10000):



    ds_size = len(ds)

    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)  # Fixed variable name

    train_ds = ds.take(train_size)
    test_ds = ds.skip(train_size).take(int(test_split * ds_size))
    val_ds = ds.skip(train_size + int(test_split * ds_size)).take(val_size)

    return train_ds, test_ds, val_ds

# %%
train_ds, test_ds, val_ds=get_dataset_partition(dataset)

# %%
print(len(train_ds)*32,len(test_ds)*32,len(val_ds)*32)
# Out:
# 1984 544 256

# %%
train_ds=train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds=val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras import layers, Model
# Define constants
IMAGE_SIZE = 256
BATCH_SIZE = 32
n_classes = 8  # Change the number of classes to 8

# Load the pre-trained DenseNet121 model (excluding the top classification layer)
base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

# Freeze the weights of the base model
base_model.trainable = False

# Add your custom classification head
x = layers.GlobalAveragePooling2D()(base_model.output)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dropout(0.5)(x)  # Add dropout layer


# Modify the output layer for 8 classes
output = layers.Dense(n_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Print the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 262, 262, 3)  0          ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 128, 128, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 128, 128, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 128, 128, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 130, 130, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 64, 64, 64)   0           ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 64, 64, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 64, 64, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 64, 64, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 64, 64, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 64, 64, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 64, 64, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 64, 64, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 64, 64, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 64, 64, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 64, 64, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 64, 64, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 64, 64, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 64, 64, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 64, 64, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 64, 64, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 64, 64, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 64, 64, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 64, 64, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 64, 64, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 64, 64, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 64, 64, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 64, 64, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 64, 64, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 64, 64, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 32, 32, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 32, 32, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 32, 32, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 32, 32, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 32, 32, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 32, 32, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 32, 32, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 32, 32, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 32, 32, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 32, 32, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 32, 32, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 32, 32, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 32, 32, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 32, 32, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 32, 32, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 32, 32, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 32, 32, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 32, 32, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 32, 32, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 32, 32, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 32, 32, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 32, 32, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 32, 32, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 32, 32, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 32, 32, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 32, 32, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 32, 32, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 32, 32, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 32, 32, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 32, 32, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 32, 32, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 32, 32, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 32, 32, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 32, 32, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 32, 32, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 32, 32, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 32, 32, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 32, 32, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 32, 32, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 32, 32, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 32, 32, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 32, 32, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 32, 32, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 32, 32, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 32, 32, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 32, 32, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 32, 32, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 32, 32, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 32, 32, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 32, 32, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 32, 32, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 32, 32, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 32, 32, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 32, 32, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 32, 32, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 32, 32, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 16, 16, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 16, 16, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 16, 16, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 16, 16, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 16, 16, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 16, 16, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 16, 16, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 16, 16, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 16, 16, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 16, 16, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 16, 16, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 16, 16, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 16, 16, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 16, 16, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 16, 16, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 16, 16, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 16, 16, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 16, 16, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 16, 16, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 16, 16, 416)  0          ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 16, 16, 416)  1664       ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 16, 16, 416)  0          ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 16, 16, 128)  53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block6_1_conv[0][0]']
# ...
#  conv5_block9_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv5_block9_1_conv[0][0]']
#  ization)
#
#  conv5_block9_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv5_block9_1_bn[0][0]']
#  n)
#
#  conv5_block9_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv5_block9_1_relu[0][0]']
#
#  conv5_block9_concat (Concatena  (None, 8, 8, 800)   0           ['conv5_block8_concat[0][0]',
#  te)                                                              'conv5_block9_2_conv[0][0]']
#
#  conv5_block10_0_bn (BatchNorma  (None, 8, 8, 800)   3200        ['conv5_block9_concat[0][0]']
#  lization)
#
#  conv5_block10_0_relu (Activati  (None, 8, 8, 800)   0           ['conv5_block10_0_bn[0][0]']
#  on)
#
#  conv5_block10_1_conv (Conv2D)  (None, 8, 8, 128)    102400      ['conv5_block10_0_relu[0][0]']
#
#  conv5_block10_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block10_1_conv[0][0]']
#  lization)
#
#  conv5_block10_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block10_1_bn[0][0]']
#  on)
#
#  conv5_block10_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block10_1_relu[0][0]']
#
#  conv5_block10_concat (Concaten  (None, 8, 8, 832)   0           ['conv5_block9_concat[0][0]',
#  ate)                                                             'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchNorma  (None, 8, 8, 832)   3328        ['conv5_block10_concat[0][0]']
#  lization)
#
#  conv5_block11_0_relu (Activati  (None, 8, 8, 832)   0           ['conv5_block11_0_bn[0][0]']
#  on)
#
#  conv5_block11_1_conv (Conv2D)  (None, 8, 8, 128)    106496      ['conv5_block11_0_relu[0][0]']
#
#  conv5_block11_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block11_1_conv[0][0]']
#  lization)
#
#  conv5_block11_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block11_1_bn[0][0]']
#  on)
#
#  conv5_block11_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block11_1_relu[0][0]']
#
#  conv5_block11_concat (Concaten  (None, 8, 8, 864)   0           ['conv5_block10_concat[0][0]',
#  ate)                                                             'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchNorma  (None, 8, 8, 864)   3456        ['conv5_block11_concat[0][0]']
#  lization)
#
#  conv5_block12_0_relu (Activati  (None, 8, 8, 864)   0           ['conv5_block12_0_bn[0][0]']
#  on)
#
#  conv5_block12_1_conv (Conv2D)  (None, 8, 8, 128)    110592      ['conv5_block12_0_relu[0][0]']
#
#  conv5_block12_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block12_1_conv[0][0]']
#  lization)
#
#  conv5_block12_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block12_1_bn[0][0]']
#  on)
#
#  conv5_block12_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block12_1_relu[0][0]']
#
#  conv5_block12_concat (Concaten  (None, 8, 8, 896)   0           ['conv5_block11_concat[0][0]',
#  ate)                                                             'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchNorma  (None, 8, 8, 896)   3584        ['conv5_block12_concat[0][0]']
#  lization)
#
#  conv5_block13_0_relu (Activati  (None, 8, 8, 896)   0           ['conv5_block13_0_bn[0][0]']
#  on)
#
#  conv5_block13_1_conv (Conv2D)  (None, 8, 8, 128)    114688      ['conv5_block13_0_relu[0][0]']
#
#  conv5_block13_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block13_1_conv[0][0]']
#  lization)
#
#  conv5_block13_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block13_1_bn[0][0]']
#  on)
#
#  conv5_block13_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block13_1_relu[0][0]']
#
#  conv5_block13_concat (Concaten  (None, 8, 8, 928)   0           ['conv5_block12_concat[0][0]',
#  ate)                                                             'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchNorma  (None, 8, 8, 928)   3712        ['conv5_block13_concat[0][0]']
#  lization)
#
#  conv5_block14_0_relu (Activati  (None, 8, 8, 928)   0           ['conv5_block14_0_bn[0][0]']
#  on)
#
#  conv5_block14_1_conv (Conv2D)  (None, 8, 8, 128)    118784      ['conv5_block14_0_relu[0][0]']
#
#  conv5_block14_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block14_1_conv[0][0]']
#  lization)
#
#  conv5_block14_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block14_1_bn[0][0]']
#  on)
#
#  conv5_block14_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block14_1_relu[0][0]']
#
#  conv5_block14_concat (Concaten  (None, 8, 8, 960)   0           ['conv5_block13_concat[0][0]',
#  ate)                                                             'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchNorma  (None, 8, 8, 960)   3840        ['conv5_block14_concat[0][0]']
#  lization)
#
#  conv5_block15_0_relu (Activati  (None, 8, 8, 960)   0           ['conv5_block15_0_bn[0][0]']
#  on)
#
#  conv5_block15_1_conv (Conv2D)  (None, 8, 8, 128)    122880      ['conv5_block15_0_relu[0][0]']
#
#  conv5_block15_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block15_1_conv[0][0]']
#  lization)
#
#  conv5_block15_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block15_1_bn[0][0]']
#  on)
#
#  conv5_block15_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block15_1_relu[0][0]']
#
#  conv5_block15_concat (Concaten  (None, 8, 8, 992)   0           ['conv5_block14_concat[0][0]',
#  ate)                                                             'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchNorma  (None, 8, 8, 992)   3968        ['conv5_block15_concat[0][0]']
#  lization)
#
#  conv5_block16_0_relu (Activati  (None, 8, 8, 992)   0           ['conv5_block16_0_bn[0][0]']
#  on)
#
#  conv5_block16_1_conv (Conv2D)  (None, 8, 8, 128)    126976      ['conv5_block16_0_relu[0][0]']
#
#  conv5_block16_1_bn (BatchNorma  (None, 8, 8, 128)   512         ['conv5_block16_1_conv[0][0]']
#  lization)
#
#  conv5_block16_1_relu (Activati  (None, 8, 8, 128)   0           ['conv5_block16_1_bn[0][0]']
#  on)
#
#  conv5_block16_2_conv (Conv2D)  (None, 8, 8, 32)     36864       ['conv5_block16_1_relu[0][0]']
#
#  conv5_block16_concat (Concaten  (None, 8, 8, 1024)  0           ['conv5_block15_concat[0][0]',
#  ate)                                                             'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 8, 8, 1024)   4096        ['conv5_block16_concat[0][0]']
#
#  relu (Activation)              (None, 8, 8, 1024)   0           ['bn[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['relu[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 128)          131200      ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout (Dropout)              (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 8)            1032        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 7,169,736
# Trainable params: 132,232
# Non-trainable params: 7,037,504
# __________________________________________________________________________________________________

# %%
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=251
)
# Out:
# Epoch 1/251
# 62/62 [==============================] - 29s 226ms/step - loss: 3.3438 - accuracy: 0.2742 - val_loss: 1.5673 - val_accuracy: 0.4805
# Epoch 2/251
# 62/62 [==============================] - 8s 130ms/step - loss: 1.6418 - accuracy: 0.4072 - val_loss: 1.3251 - val_accuracy: 0.5312
# Epoch 3/251
# 62/62 [==============================] - 9s 137ms/step - loss: 1.5324 - accuracy: 0.4363 - val_loss: 1.2077 - val_accuracy: 0.5742
# Epoch 4/251
# 62/62 [==============================] - 8s 131ms/step - loss: 1.4196 - accuracy: 0.4750 - val_loss: 1.1409 - val_accuracy: 0.5859
# Epoch 5/251
# 62/62 [==============================] - 8s 131ms/step - loss: 1.3499 - accuracy: 0.4944 - val_loss: 1.0424 - val_accuracy: 0.5820
# Epoch 6/251
# 62/62 [==============================] - 8s 129ms/step - loss: 1.2892 - accuracy: 0.5209 - val_loss: 1.0098 - val_accuracy: 0.6250
# Epoch 7/251
# 62/62 [==============================] - 8s 126ms/step - loss: 1.2659 - accuracy: 0.5306 - val_loss: 0.9636 - val_accuracy: 0.6445
# Epoch 8/251
# 62/62 [==============================] - 8s 128ms/step - loss: 1.2079 - accuracy: 0.5362 - val_loss: 0.9200 - val_accuracy: 0.6289
# Epoch 9/251
# 62/62 [==============================] - 8s 126ms/step - loss: 1.1404 - accuracy: 0.5729 - val_loss: 0.8511 - val_accuracy: 0.6641
# Epoch 10/251
# 62/62 [==============================] - 8s 128ms/step - loss: 1.1485 - accuracy: 0.5515 - val_loss: 0.8500 - val_accuracy: 0.6914
# Epoch 11/251
# 62/62 [==============================] - 8s 129ms/step - loss: 1.0934 - accuracy: 0.5749 - val_loss: 0.8368 - val_accuracy: 0.6875
# Epoch 12/251
# 62/62 [==============================] - 8s 135ms/step - loss: 1.0634 - accuracy: 0.5795 - val_loss: 0.7810 - val_accuracy: 0.6875
# Epoch 13/251
# 62/62 [==============================] - 8s 128ms/step - loss: 1.0634 - accuracy: 0.5917 - val_loss: 0.7380 - val_accuracy: 0.6953
# Epoch 14/251
# 62/62 [==============================] - 8s 130ms/step - loss: 1.0324 - accuracy: 0.6004 - val_loss: 0.7202 - val_accuracy: 0.7422
# Epoch 15/251
# 62/62 [==============================] - 8s 135ms/step - loss: 0.9646 - accuracy: 0.6340 - val_loss: 0.6605 - val_accuracy: 0.7617
# Epoch 16/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.9583 - accuracy: 0.6228 - val_loss: 0.6456 - val_accuracy: 0.7773
# Epoch 17/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.9561 - accuracy: 0.6188 - val_loss: 0.7109 - val_accuracy: 0.7344
# Epoch 18/251
# 62/62 [==============================] - 8s 133ms/step - loss: 0.9304 - accuracy: 0.6442 - val_loss: 0.6512 - val_accuracy: 0.7461
# Epoch 19/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.9068 - accuracy: 0.6493 - val_loss: 0.6141 - val_accuracy: 0.7617
# Epoch 20/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.9004 - accuracy: 0.6595 - val_loss: 0.6312 - val_accuracy: 0.7852
# Epoch 21/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.8358 - accuracy: 0.6794 - val_loss: 0.5833 - val_accuracy: 0.7930
# Epoch 22/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.8306 - accuracy: 0.6743 - val_loss: 0.5631 - val_accuracy: 0.8203
# Epoch 23/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.8265 - accuracy: 0.6784 - val_loss: 0.5765 - val_accuracy: 0.8125
# Epoch 24/251
# 62/62 [==============================] - 8s 126ms/step - loss: 0.8098 - accuracy: 0.6962 - val_loss: 0.5347 - val_accuracy: 0.8086
# Epoch 25/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.7824 - accuracy: 0.6927 - val_loss: 0.5175 - val_accuracy: 0.7969
# Epoch 26/251
# 62/62 [==============================] - 8s 134ms/step - loss: 0.8235 - accuracy: 0.6820 - val_loss: 0.5478 - val_accuracy: 0.8008
# Epoch 27/251
# 62/62 [==============================] - 8s 126ms/step - loss: 0.7873 - accuracy: 0.6962 - val_loss: 0.5335 - val_accuracy: 0.8008
# Epoch 28/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.7975 - accuracy: 0.6962 - val_loss: 0.4749 - val_accuracy: 0.8242
# Epoch 29/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.7557 - accuracy: 0.6998 - val_loss: 0.5224 - val_accuracy: 0.7930
# Epoch 30/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.7376 - accuracy: 0.7105 - val_loss: 0.4782 - val_accuracy: 0.8242
# Epoch 31/251
# 62/62 [==============================] - 8s 134ms/step - loss: 0.7108 - accuracy: 0.7187 - val_loss: 0.4757 - val_accuracy: 0.8242
# Epoch 32/251
# 62/62 [==============================] - 8s 126ms/step - loss: 0.7205 - accuracy: 0.7166 - val_loss: 0.4815 - val_accuracy: 0.8164
# Epoch 33/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.7089 - accuracy: 0.7217 - val_loss: 0.4271 - val_accuracy: 0.8281
# Epoch 34/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.7111 - accuracy: 0.7309 - val_loss: 0.4503 - val_accuracy: 0.8242
# Epoch 35/251
# 62/62 [==============================] - 8s 126ms/step - loss: 0.7034 - accuracy: 0.7273 - val_loss: 0.4591 - val_accuracy: 0.8320
# Epoch 36/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.6985 - accuracy: 0.7243 - val_loss: 0.4478 - val_accuracy: 0.8477
# Epoch 37/251
# 62/62 [==============================] - 8s 133ms/step - loss: 0.6379 - accuracy: 0.7523 - val_loss: 0.4344 - val_accuracy: 0.8750
# Epoch 38/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.7265 - accuracy: 0.7288 - val_loss: 0.4014 - val_accuracy: 0.8555
# Epoch 39/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.7120 - accuracy: 0.7181 - val_loss: 0.4272 - val_accuracy: 0.8555
# Epoch 40/251
# 62/62 [==============================] - 8s 135ms/step - loss: 0.6636 - accuracy: 0.7268 - val_loss: 0.3817 - val_accuracy: 0.8633
# Epoch 41/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.6503 - accuracy: 0.7533 - val_loss: 0.4492 - val_accuracy: 0.8359
# Epoch 42/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.6488 - accuracy: 0.7508 - val_loss: 0.4074 - val_accuracy: 0.8516
# Epoch 43/251
# 62/62 [==============================] - 8s 134ms/step - loss: 0.6665 - accuracy: 0.7345 - val_loss: 0.3987 - val_accuracy: 0.8477
# Epoch 44/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.6540 - accuracy: 0.7345 - val_loss: 0.3866 - val_accuracy: 0.8633
# Epoch 45/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.6617 - accuracy: 0.7492 - val_loss: 0.3674 - val_accuracy: 0.8633
# Epoch 46/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.6220 - accuracy: 0.7717 - val_loss: 0.3664 - val_accuracy: 0.8594
# Epoch 47/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.6391 - accuracy: 0.7559 - val_loss: 0.3805 - val_accuracy: 0.8594
# Epoch 48/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.6324 - accuracy: 0.7472 - val_loss: 0.3567 - val_accuracy: 0.8672
# Epoch 49/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.5851 - accuracy: 0.7712 - val_loss: 0.3361 - val_accuracy: 0.8867
# Epoch 50/251
# 62/62 [==============================] - 8s 134ms/step - loss: 0.5690 - accuracy: 0.7737 - val_loss: 0.3461 - val_accuracy: 0.8750
# Epoch 51/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.6421 - accuracy: 0.7324 - val_loss: 0.4012 - val_accuracy: 0.8438
# Epoch 52/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.6497 - accuracy: 0.7452 - val_loss: 0.3836 - val_accuracy: 0.8672
# Epoch 53/251
# 62/62 [==============================] - 8s 133ms/step - loss: 0.6308 - accuracy: 0.7503 - val_loss: 0.3740 - val_accuracy: 0.8594
# Epoch 54/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.5904 - accuracy: 0.7625 - val_loss: 0.3657 - val_accuracy: 0.8516
# Epoch 55/251
# 62/62 [==============================] - 8s 134ms/step - loss: 0.5954 - accuracy: 0.7640 - val_loss: 0.3026 - val_accuracy: 0.8711
# Epoch 56/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.5642 - accuracy: 0.7732 - val_loss: 0.3242 - val_accuracy: 0.8750
# Epoch 57/251
# 62/62 [==============================] - 8s 131ms/step - loss: 0.5688 - accuracy: 0.7783 - val_loss: 0.2924 - val_accuracy: 0.8828
# Epoch 58/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.5246 - accuracy: 0.7936 - val_loss: 0.2732 - val_accuracy: 0.8789
# Epoch 59/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.5774 - accuracy: 0.7762 - val_loss: 0.3291 - val_accuracy: 0.8711
# Epoch 60/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.5430 - accuracy: 0.7844 - val_loss: 0.3247 - val_accuracy: 0.8633
# Epoch 61/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.5287 - accuracy: 0.7910 - val_loss: 0.3131 - val_accuracy: 0.8594
# Epoch 62/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.5259 - accuracy: 0.7941 - val_loss: 0.3180 - val_accuracy: 0.8828
# Epoch 63/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.5182 - accuracy: 0.7915 - val_loss: 0.3285 - val_accuracy: 0.8633
# Epoch 64/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.5241 - accuracy: 0.7880 - val_loss: 0.3063 - val_accuracy: 0.9102
# Epoch 65/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.5263 - accuracy: 0.7910 - val_loss: 0.3359 - val_accuracy: 0.8672
# Epoch 66/251
# 62/62 [==============================] - 8s 133ms/step - loss: 0.4919 - accuracy: 0.8058 - val_loss: 0.2982 - val_accuracy: 0.8789
# Epoch 67/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.4875 - accuracy: 0.8033 - val_loss: 0.2780 - val_accuracy: 0.9062
# Epoch 68/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.5124 - accuracy: 0.7992 - val_loss: 0.2944 - val_accuracy: 0.8828
# Epoch 69/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.4818 - accuracy: 0.8089 - val_loss: 0.2770 - val_accuracy: 0.9023
# Epoch 70/251
# 62/62 [==============================] - 8s 134ms/step - loss: 0.5249 - accuracy: 0.7885 - val_loss: 0.3584 - val_accuracy: 0.8555
# Epoch 71/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.5357 - accuracy: 0.7829 - val_loss: 0.3102 - val_accuracy: 0.8867
# Epoch 72/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.5067 - accuracy: 0.7910 - val_loss: 0.3239 - val_accuracy: 0.8867
# Epoch 73/251
# 62/62 [==============================] - 8s 133ms/step - loss: 0.5026 - accuracy: 0.7992 - val_loss: 0.2809 - val_accuracy: 0.8672
# Epoch 74/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.4764 - accuracy: 0.8155 - val_loss: 0.3196 - val_accuracy: 0.9023
# Epoch 75/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.4826 - accuracy: 0.8104 - val_loss: 0.2435 - val_accuracy: 0.9102
# Epoch 76/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.4703 - accuracy: 0.8119 - val_loss: 0.2756 - val_accuracy: 0.8906
# Epoch 77/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.4524 - accuracy: 0.8135 - val_loss: 0.2962 - val_accuracy: 0.9023
# Epoch 78/251
# 62/62 [==============================] - 8s 135ms/step - loss: 0.4483 - accuracy: 0.8186 - val_loss: 0.2618 - val_accuracy: 0.8984
# Epoch 79/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.4637 - accuracy: 0.8078 - val_loss: 0.2753 - val_accuracy: 0.9023
# Epoch 80/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.4551 - accuracy: 0.8191 - val_loss: 0.2813 - val_accuracy: 0.8945
# Epoch 81/251
# 62/62 [==============================] - 8s 134ms/step - loss: 0.4539 - accuracy: 0.8119 - val_loss: 0.2757 - val_accuracy: 0.8945
# Epoch 82/251
# 62/62 [==============================] - 8s 135ms/step - loss: 0.4609 - accuracy: 0.8140 - val_loss: 0.2400 - val_accuracy: 0.9180
# Epoch 83/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.4387 - accuracy: 0.8242 - val_loss: 0.2884 - val_accuracy: 0.8945
# Epoch 84/251
# 62/62 [==============================] - 8s 135ms/step - loss: 0.4600 - accuracy: 0.8175 - val_loss: 0.2824 - val_accuracy: 0.8984
# Epoch 85/251
# 62/62 [==============================] - 8s 126ms/step - loss: 0.4513 - accuracy: 0.8140 - val_loss: 0.2498 - val_accuracy: 0.9023
# Epoch 86/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.4415 - accuracy: 0.8277 - val_loss: 0.2685 - val_accuracy: 0.8984
# Epoch 87/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.4110 - accuracy: 0.8287 - val_loss: 0.2406 - val_accuracy: 0.9258
# Epoch 88/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.4418 - accuracy: 0.8221 - val_loss: 0.2435 - val_accuracy: 0.9062
# Epoch 89/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.4342 - accuracy: 0.8155 - val_loss: 0.2554 - val_accuracy: 0.9102
# Epoch 90/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.4031 - accuracy: 0.8389 - val_loss: 0.2482 - val_accuracy: 0.9219
# Epoch 91/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.4452 - accuracy: 0.8206 - val_loss: 0.2315 - val_accuracy: 0.9180
# Epoch 92/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.4328 - accuracy: 0.8287 - val_loss: 0.2312 - val_accuracy: 0.9219
# Epoch 93/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.4232 - accuracy: 0.8333 - val_loss: 0.2804 - val_accuracy: 0.9062
# Epoch 94/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.3884 - accuracy: 0.8491 - val_loss: 0.2425 - val_accuracy: 0.9180
# Epoch 95/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.3868 - accuracy: 0.8374 - val_loss: 0.2285 - val_accuracy: 0.9141
# Epoch 96/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.4698 - accuracy: 0.8140 - val_loss: 0.2609 - val_accuracy: 0.8945
# Epoch 97/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.4327 - accuracy: 0.8165 - val_loss: 0.3516 - val_accuracy: 0.8711
# Epoch 98/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.4308 - accuracy: 0.8298 - val_loss: 0.2091 - val_accuracy: 0.9258
# Epoch 99/251
# 62/62 [==============================] - 8s 135ms/step - loss: 0.4019 - accuracy: 0.8272 - val_loss: 0.2237 - val_accuracy: 0.9336
# Epoch 100/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.4070 - accuracy: 0.8374 - val_loss: 0.2603 - val_accuracy: 0.8984
# Epoch 101/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.4022 - accuracy: 0.8354 - val_loss: 0.2223 - val_accuracy: 0.9141
# Epoch 102/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.4225 - accuracy: 0.8262 - val_loss: 0.2110 - val_accuracy: 0.9258
# Epoch 103/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.3728 - accuracy: 0.8440 - val_loss: 0.2383 - val_accuracy: 0.9102
# Epoch 104/251
# 62/62 [==============================] - 8s 134ms/step - loss: 0.4261 - accuracy: 0.8318 - val_loss: 0.2582 - val_accuracy: 0.9141
# Epoch 105/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.4372 - accuracy: 0.8282 - val_loss: 0.2320 - val_accuracy: 0.9297
# Epoch 106/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.3993 - accuracy: 0.8384 - val_loss: 0.2380 - val_accuracy: 0.9336
# Epoch 107/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.3932 - accuracy: 0.8471 - val_loss: 0.2289 - val_accuracy: 0.9219
# Epoch 108/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.4063 - accuracy: 0.8461 - val_loss: 0.2002 - val_accuracy: 0.9141
# Epoch 109/251
# 62/62 [==============================] - 8s 135ms/step - loss: 0.4379 - accuracy: 0.8196 - val_loss: 0.2404 - val_accuracy: 0.9180
# Epoch 110/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.4126 - accuracy: 0.8267 - val_loss: 0.1953 - val_accuracy: 0.9336
# Epoch 111/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.3865 - accuracy: 0.8542 - val_loss: 0.2082 - val_accuracy: 0.9219
# Epoch 112/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.3789 - accuracy: 0.8461 - val_loss: 0.2230 - val_accuracy: 0.9180
# Epoch 113/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3762 - accuracy: 0.8502 - val_loss: 0.2448 - val_accuracy: 0.9023
# Epoch 114/251
# 62/62 [==============================] - 8s 135ms/step - loss: 0.3756 - accuracy: 0.8466 - val_loss: 0.2300 - val_accuracy: 0.9219
# Epoch 115/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.3446 - accuracy: 0.8527 - val_loss: 0.2392 - val_accuracy: 0.9180
# Epoch 116/251
# 62/62 [==============================] - 8s 131ms/step - loss: 0.3711 - accuracy: 0.8476 - val_loss: 0.2099 - val_accuracy: 0.9102
# Epoch 117/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.4209 - accuracy: 0.8226 - val_loss: 0.2261 - val_accuracy: 0.9180
# Epoch 118/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.3592 - accuracy: 0.8542 - val_loss: 0.2310 - val_accuracy: 0.9141
# Epoch 119/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.3857 - accuracy: 0.8481 - val_loss: 0.2432 - val_accuracy: 0.9141
# Epoch 120/251
# 62/62 [==============================] - 8s 134ms/step - loss: 0.3531 - accuracy: 0.8532 - val_loss: 0.2296 - val_accuracy: 0.9141
# Epoch 121/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.3441 - accuracy: 0.8644 - val_loss: 0.1803 - val_accuracy: 0.9375
# Epoch 122/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3566 - accuracy: 0.8496 - val_loss: 0.2183 - val_accuracy: 0.9336
# Epoch 123/251
# 62/62 [==============================] - 8s 134ms/step - loss: 0.3503 - accuracy: 0.8639 - val_loss: 0.1887 - val_accuracy: 0.9297
# Epoch 124/251
# 62/62 [==============================] - 8s 136ms/step - loss: 0.3926 - accuracy: 0.8471 - val_loss: 0.1955 - val_accuracy: 0.9297
# Epoch 125/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.4037 - accuracy: 0.8384 - val_loss: 0.2481 - val_accuracy: 0.9141
# Epoch 126/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.4338 - accuracy: 0.8196 - val_loss: 0.2194 - val_accuracy: 0.9258
# Epoch 127/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.3420 - accuracy: 0.8624 - val_loss: 0.2312 - val_accuracy: 0.9180
# Epoch 128/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3645 - accuracy: 0.8476 - val_loss: 0.2692 - val_accuracy: 0.9219
# Epoch 129/251
# 62/62 [==============================] - 8s 134ms/step - loss: 0.3387 - accuracy: 0.8593 - val_loss: 0.2749 - val_accuracy: 0.9102
# Epoch 130/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.3720 - accuracy: 0.8552 - val_loss: 0.2534 - val_accuracy: 0.9258
# Epoch 131/251
# 62/62 [==============================] - 8s 131ms/step - loss: 0.3342 - accuracy: 0.8573 - val_loss: 0.2023 - val_accuracy: 0.9180
# Epoch 132/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.3433 - accuracy: 0.8614 - val_loss: 0.2036 - val_accuracy: 0.9414
# Epoch 133/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3546 - accuracy: 0.8491 - val_loss: 0.2397 - val_accuracy: 0.9141
# Epoch 134/251
# 62/62 [==============================] - 8s 135ms/step - loss: 0.3491 - accuracy: 0.8634 - val_loss: 0.1938 - val_accuracy: 0.9453
# Epoch 135/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.3349 - accuracy: 0.8583 - val_loss: 0.1956 - val_accuracy: 0.9297
# Epoch 136/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.3660 - accuracy: 0.8445 - val_loss: 0.2324 - val_accuracy: 0.9180
# Epoch 137/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.3304 - accuracy: 0.8660 - val_loss: 0.2705 - val_accuracy: 0.9258
# Epoch 138/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.3561 - accuracy: 0.8547 - val_loss: 0.2153 - val_accuracy: 0.9336
# Epoch 139/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3330 - accuracy: 0.8583 - val_loss: 0.2086 - val_accuracy: 0.9297
# Epoch 140/251
# 62/62 [==============================] - 8s 136ms/step - loss: 0.3338 - accuracy: 0.8746 - val_loss: 0.2196 - val_accuracy: 0.9336
# Epoch 141/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.3094 - accuracy: 0.8721 - val_loss: 0.2322 - val_accuracy: 0.9375
# Epoch 142/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3351 - accuracy: 0.8649 - val_loss: 0.2170 - val_accuracy: 0.9219
# Epoch 143/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.3240 - accuracy: 0.8685 - val_loss: 0.1994 - val_accuracy: 0.9375
# Epoch 144/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3274 - accuracy: 0.8619 - val_loss: 0.2368 - val_accuracy: 0.9336
# Epoch 145/251
# 62/62 [==============================] - 8s 135ms/step - loss: 0.3525 - accuracy: 0.8527 - val_loss: 0.1968 - val_accuracy: 0.9297
# Epoch 146/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.3591 - accuracy: 0.8558 - val_loss: 0.2211 - val_accuracy: 0.9219
# Epoch 147/251
# 62/62 [==============================] - 8s 126ms/step - loss: 0.3956 - accuracy: 0.8415 - val_loss: 0.2934 - val_accuracy: 0.8984
# Epoch 148/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.3940 - accuracy: 0.8369 - val_loss: 0.2166 - val_accuracy: 0.9180
# Epoch 149/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.3558 - accuracy: 0.8496 - val_loss: 0.2393 - val_accuracy: 0.9375
# Epoch 150/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3631 - accuracy: 0.8466 - val_loss: 0.2399 - val_accuracy: 0.9336
# Epoch 151/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3318 - accuracy: 0.8609 - val_loss: 0.2131 - val_accuracy: 0.9336
# Epoch 152/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.3278 - accuracy: 0.8716 - val_loss: 0.2003 - val_accuracy: 0.9414
# Epoch 153/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3265 - accuracy: 0.8629 - val_loss: 0.2297 - val_accuracy: 0.9453
# Epoch 154/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3308 - accuracy: 0.8690 - val_loss: 0.1911 - val_accuracy: 0.9414
# Epoch 155/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.3412 - accuracy: 0.8558 - val_loss: 0.2070 - val_accuracy: 0.9492
# Epoch 156/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3591 - accuracy: 0.8547 - val_loss: 0.1952 - val_accuracy: 0.9375
# Epoch 157/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.3273 - accuracy: 0.8726 - val_loss: 0.1931 - val_accuracy: 0.9297
# Epoch 158/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.3469 - accuracy: 0.8614 - val_loss: 0.2203 - val_accuracy: 0.9141
# Epoch 159/251
# 62/62 [==============================] - 8s 131ms/step - loss: 0.3770 - accuracy: 0.8445 - val_loss: 0.2422 - val_accuracy: 0.9141
# Epoch 160/251
# 62/62 [==============================] - 8s 134ms/step - loss: 0.3524 - accuracy: 0.8558 - val_loss: 0.2243 - val_accuracy: 0.9258
# Epoch 161/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3824 - accuracy: 0.8532 - val_loss: 0.2297 - val_accuracy: 0.9219
# Epoch 162/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3773 - accuracy: 0.8466 - val_loss: 0.2751 - val_accuracy: 0.9141
# Epoch 163/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.3696 - accuracy: 0.8400 - val_loss: 0.2127 - val_accuracy: 0.9414
# Epoch 164/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3189 - accuracy: 0.8690 - val_loss: 0.2185 - val_accuracy: 0.9258
# Epoch 165/251
# 62/62 [==============================] - 8s 134ms/step - loss: 0.3316 - accuracy: 0.8670 - val_loss: 0.1988 - val_accuracy: 0.9336
# Epoch 166/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.3678 - accuracy: 0.8517 - val_loss: 0.1981 - val_accuracy: 0.9375
# Epoch 167/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3528 - accuracy: 0.8588 - val_loss: 0.2557 - val_accuracy: 0.9297
# Epoch 168/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.3964 - accuracy: 0.8466 - val_loss: 0.2126 - val_accuracy: 0.9375
# Epoch 169/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.3596 - accuracy: 0.8466 - val_loss: 0.2590 - val_accuracy: 0.9102
# Epoch 170/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3337 - accuracy: 0.8644 - val_loss: 0.2133 - val_accuracy: 0.9219
# Epoch 171/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.3535 - accuracy: 0.8456 - val_loss: 0.1864 - val_accuracy: 0.9297
# Epoch 172/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3527 - accuracy: 0.8660 - val_loss: 0.2408 - val_accuracy: 0.9219
# Epoch 173/251
# 62/62 [==============================] - 8s 136ms/step - loss: 0.2907 - accuracy: 0.8741 - val_loss: 0.2267 - val_accuracy: 0.9297
# Epoch 174/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.3088 - accuracy: 0.8777 - val_loss: 0.2268 - val_accuracy: 0.9297
# Epoch 175/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3128 - accuracy: 0.8731 - val_loss: 0.2221 - val_accuracy: 0.9414
# Epoch 176/251
# 62/62 [==============================] - 8s 134ms/step - loss: 0.3058 - accuracy: 0.8695 - val_loss: 0.1855 - val_accuracy: 0.9336
# Epoch 177/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.3101 - accuracy: 0.8665 - val_loss: 0.2287 - val_accuracy: 0.9375
# Epoch 178/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3552 - accuracy: 0.8532 - val_loss: 0.2156 - val_accuracy: 0.9180
# Epoch 179/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3274 - accuracy: 0.8649 - val_loss: 0.2239 - val_accuracy: 0.9336
# Epoch 180/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.3396 - accuracy: 0.8502 - val_loss: 0.2027 - val_accuracy: 0.9375
# Epoch 181/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.3036 - accuracy: 0.8767 - val_loss: 0.1910 - val_accuracy: 0.9492
# Epoch 182/251
# 62/62 [==============================] - 8s 131ms/step - loss: 0.2797 - accuracy: 0.8843 - val_loss: 0.2306 - val_accuracy: 0.9375
# Epoch 183/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.3094 - accuracy: 0.8746 - val_loss: 0.2386 - val_accuracy: 0.9297
# Epoch 184/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.3253 - accuracy: 0.8736 - val_loss: 0.2092 - val_accuracy: 0.9258
# Epoch 185/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3109 - accuracy: 0.8818 - val_loss: 0.2257 - val_accuracy: 0.9297
# Epoch 186/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.3391 - accuracy: 0.8654 - val_loss: 0.2204 - val_accuracy: 0.9297
# Epoch 187/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3406 - accuracy: 0.8624 - val_loss: 0.2672 - val_accuracy: 0.9062
# Epoch 188/251
# 62/62 [==============================] - 8s 135ms/step - loss: 0.3419 - accuracy: 0.8634 - val_loss: 0.1922 - val_accuracy: 0.9492
# Epoch 189/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.3248 - accuracy: 0.8619 - val_loss: 0.2205 - val_accuracy: 0.9414
# Epoch 190/251
# 62/62 [==============================] - 8s 131ms/step - loss: 0.3806 - accuracy: 0.8430 - val_loss: 0.2654 - val_accuracy: 0.9180
# Epoch 191/251
# 62/62 [==============================] - 8s 134ms/step - loss: 0.3351 - accuracy: 0.8614 - val_loss: 0.2044 - val_accuracy: 0.9297
# Epoch 192/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.3256 - accuracy: 0.8598 - val_loss: 0.1854 - val_accuracy: 0.9492
# Epoch 193/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3231 - accuracy: 0.8644 - val_loss: 0.2705 - val_accuracy: 0.9258
# Epoch 194/251
# 62/62 [==============================] - 8s 131ms/step - loss: 0.4062 - accuracy: 0.8313 - val_loss: 0.2414 - val_accuracy: 0.9258
# Epoch 195/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.3141 - accuracy: 0.8777 - val_loss: 0.2003 - val_accuracy: 0.9414
# Epoch 196/251
# 62/62 [==============================] - 8s 131ms/step - loss: 0.3048 - accuracy: 0.8879 - val_loss: 0.2049 - val_accuracy: 0.9297
# Epoch 197/251
# 62/62 [==============================] - 8s 131ms/step - loss: 0.3194 - accuracy: 0.8746 - val_loss: 0.1821 - val_accuracy: 0.9453
# Epoch 198/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.3054 - accuracy: 0.8756 - val_loss: 0.2059 - val_accuracy: 0.9336
# Epoch 199/251
# 62/62 [==============================] - 8s 131ms/step - loss: 0.3168 - accuracy: 0.8654 - val_loss: 0.2196 - val_accuracy: 0.9453
# Epoch 200/251
# 62/62 [==============================] - 8s 134ms/step - loss: 0.3135 - accuracy: 0.8705 - val_loss: 0.1942 - val_accuracy: 0.9375
# Epoch 201/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3159 - accuracy: 0.8680 - val_loss: 0.2103 - val_accuracy: 0.9414
# Epoch 202/251
# 62/62 [==============================] - 8s 137ms/step - loss: 0.3403 - accuracy: 0.8507 - val_loss: 0.2223 - val_accuracy: 0.9375
# Epoch 203/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.3428 - accuracy: 0.8598 - val_loss: 0.2843 - val_accuracy: 0.9219
# Epoch 204/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3220 - accuracy: 0.8675 - val_loss: 0.2337 - val_accuracy: 0.9336
# Epoch 205/251
# 62/62 [==============================] - 8s 134ms/step - loss: 0.3466 - accuracy: 0.8496 - val_loss: 0.2423 - val_accuracy: 0.9258
# Epoch 206/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.3156 - accuracy: 0.8680 - val_loss: 0.2329 - val_accuracy: 0.9453
# Epoch 207/251
# 62/62 [==============================] - 8s 131ms/step - loss: 0.3106 - accuracy: 0.8690 - val_loss: 0.2595 - val_accuracy: 0.9297
# Epoch 208/251
# 62/62 [==============================] - 9s 137ms/step - loss: 0.3174 - accuracy: 0.8665 - val_loss: 0.1983 - val_accuracy: 0.9414
# Epoch 209/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.3192 - accuracy: 0.8670 - val_loss: 0.1941 - val_accuracy: 0.9414
# Epoch 210/251
# 62/62 [==============================] - 8s 132ms/step - loss: 0.3160 - accuracy: 0.8710 - val_loss: 0.1697 - val_accuracy: 0.9492
# Epoch 211/251
# 62/62 [==============================] - 8s 136ms/step - loss: 0.2736 - accuracy: 0.8828 - val_loss: 0.2451 - val_accuracy: 0.9297
# Epoch 212/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.2957 - accuracy: 0.8782 - val_loss: 0.2055 - val_accuracy: 0.9453
# Epoch 213/251
# 62/62 [==============================] - 8s 131ms/step - loss: 0.3123 - accuracy: 0.8695 - val_loss: 0.2435 - val_accuracy: 0.9297
# Epoch 214/251
# 62/62 [==============================] - 8s 134ms/step - loss: 0.3058 - accuracy: 0.8787 - val_loss: 0.2400 - val_accuracy: 0.9414
# Epoch 215/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3088 - accuracy: 0.8690 - val_loss: 0.2116 - val_accuracy: 0.9297
# Epoch 216/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.2754 - accuracy: 0.8818 - val_loss: 0.2463 - val_accuracy: 0.9180
# Epoch 217/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.3277 - accuracy: 0.8588 - val_loss: 0.2845 - val_accuracy: 0.9258
# Epoch 218/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3377 - accuracy: 0.8639 - val_loss: 0.3073 - val_accuracy: 0.9141
# Epoch 219/251
# 62/62 [==============================] - 8s 134ms/step - loss: 0.3079 - accuracy: 0.8654 - val_loss: 0.2595 - val_accuracy: 0.9336
# Epoch 220/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.3355 - accuracy: 0.8654 - val_loss: 0.3073 - val_accuracy: 0.9297
# Epoch 221/251
# 62/62 [==============================] - 8s 131ms/step - loss: 0.2921 - accuracy: 0.8838 - val_loss: 0.2317 - val_accuracy: 0.9336
# Epoch 222/251
# 62/62 [==============================] - 8s 135ms/step - loss: 0.3069 - accuracy: 0.8823 - val_loss: 0.2228 - val_accuracy: 0.9375
# Epoch 223/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3235 - accuracy: 0.8634 - val_loss: 0.1732 - val_accuracy: 0.9453
# Epoch 224/251
# 62/62 [==============================] - 8s 132ms/step - loss: 0.2966 - accuracy: 0.8756 - val_loss: 0.1629 - val_accuracy: 0.9492
# Epoch 225/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.2946 - accuracy: 0.8828 - val_loss: 0.2309 - val_accuracy: 0.9336
# Epoch 226/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.2718 - accuracy: 0.8874 - val_loss: 0.2104 - val_accuracy: 0.9297
# Epoch 227/251
# 62/62 [==============================] - 8s 131ms/step - loss: 0.2960 - accuracy: 0.8802 - val_loss: 0.2180 - val_accuracy: 0.9219
# Epoch 228/251
# 62/62 [==============================] - 8s 134ms/step - loss: 0.3006 - accuracy: 0.8787 - val_loss: 0.2242 - val_accuracy: 0.9453
# Epoch 229/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.2998 - accuracy: 0.8756 - val_loss: 0.1864 - val_accuracy: 0.9375
# Epoch 230/251
# 62/62 [==============================] - 8s 132ms/step - loss: 0.3273 - accuracy: 0.8583 - val_loss: 0.2214 - val_accuracy: 0.9258
# Epoch 231/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.2981 - accuracy: 0.8675 - val_loss: 0.2099 - val_accuracy: 0.9414
# Epoch 232/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.3325 - accuracy: 0.8552 - val_loss: 0.2182 - val_accuracy: 0.9453
# Epoch 233/251
# 62/62 [==============================] - 8s 131ms/step - loss: 0.3008 - accuracy: 0.8823 - val_loss: 0.2343 - val_accuracy: 0.9375
# Epoch 234/251
# 62/62 [==============================] - 8s 127ms/step - loss: 0.3060 - accuracy: 0.8685 - val_loss: 0.2216 - val_accuracy: 0.9414
# Epoch 235/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.2927 - accuracy: 0.8746 - val_loss: 0.2306 - val_accuracy: 0.9336
# Epoch 236/251
# 62/62 [==============================] - 8s 135ms/step - loss: 0.2842 - accuracy: 0.8818 - val_loss: 0.2675 - val_accuracy: 0.9219
# Epoch 237/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.2892 - accuracy: 0.8797 - val_loss: 0.2304 - val_accuracy: 0.9297
# Epoch 238/251
# 62/62 [==============================] - 8s 136ms/step - loss: 0.3195 - accuracy: 0.8670 - val_loss: 0.2317 - val_accuracy: 0.9375
# Epoch 239/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.3116 - accuracy: 0.8675 - val_loss: 0.2567 - val_accuracy: 0.9414
# Epoch 240/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.2962 - accuracy: 0.8746 - val_loss: 0.2269 - val_accuracy: 0.9453
# Epoch 241/251
# 62/62 [==============================] - 8s 131ms/step - loss: 0.3093 - accuracy: 0.8710 - val_loss: 0.2190 - val_accuracy: 0.9453
# Epoch 242/251
# 62/62 [==============================] - 8s 129ms/step - loss: 0.3442 - accuracy: 0.8451 - val_loss: 0.2106 - val_accuracy: 0.9297
# Epoch 243/251
# 62/62 [==============================] - 8s 131ms/step - loss: 0.3227 - accuracy: 0.8716 - val_loss: 0.2384 - val_accuracy: 0.9453
# Epoch 244/251
# 62/62 [==============================] - 8s 136ms/step - loss: 0.2994 - accuracy: 0.8833 - val_loss: 0.2079 - val_accuracy: 0.9453
# Epoch 245/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.3126 - accuracy: 0.8756 - val_loss: 0.1974 - val_accuracy: 0.9453
# Epoch 246/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3343 - accuracy: 0.8675 - val_loss: 0.2406 - val_accuracy: 0.9258
# Epoch 247/251
# 62/62 [==============================] - 8s 135ms/step - loss: 0.3108 - accuracy: 0.8654 - val_loss: 0.3027 - val_accuracy: 0.9219
# Epoch 248/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.2887 - accuracy: 0.8818 - val_loss: 0.2445 - val_accuracy: 0.9258
# Epoch 249/251
# 62/62 [==============================] - 8s 130ms/step - loss: 0.3382 - accuracy: 0.8634 - val_loss: 0.2440 - val_accuracy: 0.9375
# Epoch 250/251
# 62/62 [==============================] - 8s 136ms/step - loss: 0.3340 - accuracy: 0.8644 - val_loss: 0.2728 - val_accuracy: 0.9297
# Epoch 251/251
# 62/62 [==============================] - 8s 128ms/step - loss: 0.2953 - accuracy: 0.8772 - val_loss: 0.2035 - val_accuracy: 0.9375

# %%
tf.keras.backend.clear_session()
del train_ds
del val_ds

# %%
import gc
gc.collect()
# Out:
# 4

# %%
test_ds=test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
scores=model.evaluate(test_ds)
scores
# Out:
# 17/17 [==============================] - 2s 115ms/step - loss: 0.6626 - accuracy: 0.9026
# [0.6626089215278625, 0.9025735259056091]

# %%
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']
import matplotlib.pyplot as plt
import math

# %%
EPOCHS=251
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.plot(range(EPOCHS),acc,label='Training Accuracy')
plt.legend(loc='lower right')
plt.title('Training')

plt.subplot(1,2,1)
plt.plot(range(EPOCHS),val_acc,label='validation Accuracy')
plt.legend(loc='lower right')
plt.title('Validation Accuracy')

plt.subplot(1,2,2)
plt.plot(range(EPOCHS),acc,label='Training loss')
plt.legend(loc='upper right')
plt.title('Training Loss')

plt.subplot(1,2,2)
plt.plot(range(EPOCHS),val_acc,label='validation loss')
plt.legend(loc='upper right')
plt.title('Validation Loss')



plt.tight_layout()
plt.show()

# %%
EPOCHS=251
plt.figure(figsize=(12,6))

plt.subplot(2,2,1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.legend(loc='lower right')
plt.title('Training Accuracy')

plt.subplot(2,2,2)
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Validation Accuracy')

plt.subplot(2,2,3)
plt.plot(range(EPOCHS), loss, label='Training Loss')  # Changed to 'loss'
plt.legend(loc='upper right')
plt.title('Training Loss')

plt.subplot(2,2,4)
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')  # Changed to 'val_loss'
plt.legend(loc='upper right')
plt.title('Validation Loss')

plt.tight_layout()
plt.show()

# %%
i=5
import numpy as np
for images_batch, labels_batch in test_ds.take(1):

  first_image=images_batch[i].numpy().astype("uint8")

  print("first image to predict")
  plt.imshow(first_image)

  print("label: ", class_names[labels_batch[i].numpy()])
  batch_prediction=model.predict(images_batch)
  print("predicted Label: ",class_names[np.argmax(batch_prediction[i])])
# Out:
# first image to predict
# label:  Powdery mildew
# 1/1 [==============================] - 2s 2s/step
# predicted Label:  Powdery mildew

# %%
def predict(model, img):
  img_array=tf.keras.preprocessing.image.img_to_array(images[i].numpy())
  img_array=tf.expand_dims(img_array,0)

  predictions=model.predict(img_array)
  predicted_class= class_names[np.argmax(predictions[0])]
  confidence=round(100*np.max(predictions[0]),2)
  return predicted_class,confidence

# %%
plt.figure(figsize=(15,15))
for images, labels in test_ds.take(1):

  for i in range(9):
    ax=plt.subplot(3,3,i+1)
    plt.imshow(images[i].numpy().astype("uint8"))
    predicted_class,confidence=predict(model,images[i].numpy())

    actual_class=class_names[labels[i]]
    plt.title(f"Actual: {actual_class},\n predicted: {predicted_class} \n confidence: {confidence}%")
    plt.axis("off")
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 32ms/step

# %%
import zipfile
from google.colab import files
import os

# %%
model.save('m_model_dense.h5')
